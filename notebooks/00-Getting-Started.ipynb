# %%
# Show Python and environment info
import sys, os
print('Python', sys.version)
print('Working dir:', os.getcwd())
print('List notebooks folder contents:')
print(os.listdir('.'))
# Out:
# Python 3.11.14 (main, Nov 18 2025, 05:57:35) [GCC 14.2.0]
# Working dir: /app/notebooks
# List notebooks folder contents:
# ['.ipynb_checkpoints', '00-Getting-Started.ipynb', '01-Data-Capture.ipynb', '02-Quick-Drive-Simulation.ipynb', '03-Visualize-Recorded-Data.ipynb', 'sample_data']

# %% [markdown]
# ## Quick test: run a small vehicle example
# The code below demonstrates importing the `donkeycar` package and printing its version. This verifies that the editable install inside the container is available.

# %%
# Import donkeycar and print version (editable install should be present)
try:
    import donkeycar
    print('donkeycar package version:', getattr(donkeycar, '__version__', 'unknown'))
except Exception as e:
    print('Failed to import donkeycar:', e)
# Out:
# donkeycar package version: 5.2.dev5
